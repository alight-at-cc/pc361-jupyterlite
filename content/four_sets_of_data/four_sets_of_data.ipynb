# %% [markdown]
# ## Comparing Data Sets
# This exercise is about excluding data and comparing sets of measurements.  In the file, "quartet.txt" are four sets of unitless x-y data.  For our purposes, let's imagine that both values are position of a supposedly stationary object in two dimensions (in cm).  Your task is to compare these datasets to see whether they should be considered multiples of the same measurements or not.

# %%
#import useful modules and load data

import numpy as np
import matplotlib.pyplot as plt
#we'll need this later:
from scipy.special import erf, erfc

#load data into individual x and y arrays
x1,y1,x2,y2,x3,y3,x4,y4 = np.loadtxt("quartet_data.csv", delimiter=',', skiprows=1, unpack=True)

# %% [markdown]
# **Task 1:**
# First, use some general metrics to compare the datasets.  For each set of y-values, print out:
# 1. The mean
# 2. The minimum and maximum values
# 2. The standard deviation
# 3. The standard deviation of the mean

# %% [markdown]
# **Task 2:**
# Now look at the x-data in the same way.  Print out:
# 1. The mean
# 2. The minimum and maximum values
# 2. The standard deviation
# 3. The standard deviation of the mean

# %% [markdown]
# **Question:** From these considerations alone, do you think it is plausible that these data are derived from similar motions?  Write your answer and explain your reasoning in the cell below:

# %% [markdown]
# **Task 3:**
# Now plot the data and see whether you think it's plausible they all come from similar motions.  Be deliberate about your choice of marker/linestyle/etc.  You may want to use `plt.subplots` to make a nice array of axes.  I've written some code snippets to get you started if you want to go this direction:
#
# ```
# fig,axes = plt.subplots(2,2,gridspec_kw={"hspace":0.3,"wspace":0.3})
#
# xdata = [x1,x2,x3,x4]
# ydata = [y1,y2,y3,y4]
# for ii,ax in enumerate(axes.flat):
#     ax.plot(xdata[ii],ydata[ii])
# ```

# %% [markdown]
# **Question:** Now do you think it is plausible that these data are derived from similar motions?  Write your answer and explain your reasoning in the cell below:

# %% [markdown]
# ## Excluding Data
# Now that we have a sense that these datasets are not all similar, let's look at each more closely.
#
# **Task 4**:
# First, go through and identify any outliers.  Look at the plots and see where you might suspect that a data point doesn't represent what it is supposed to.  If Chauvenet's criterion is met, remove that datapoint from the set.  Assume that the measurement uncertainty is small compared to the statistical spread in the data points.  The error function mentioned on page 136 of Taylor, which gives the probability of a measurement being within $t\sigma$ of the mean is `scipy.special.erf()` and its complement (probability outside $t\sigma$) is `scipy.special.erfc()`.  We've imported these to the local namespace as just `erf()` and `erfc()` so that they are easier to write here.
#
# Which data sets do you plan to analyze and why?

# %%
#start your analysis here
